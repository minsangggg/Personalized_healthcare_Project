# %%
import re, requests, json, time, random
from bs4 import BeautifulSoup
import pandas as pd
import os

BASE = "https://www.10000recipe.com"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# ✅ cat4 분류
CAT4_MAP = {
    63: "밑반찬", 56: "메인반찬", 54: "국/탕", 55: "찌개",
    53: "면/만두", 52: "밥/죽/떡", 61: "퓨전", 65: "양식", 64: "샐러드", 68: "스프", 62: "기타"
}

# ✅ 공통 파서
def get_soup(url):
    r = requests.get(url, headers=HEADERS, timeout=15)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")

# ✅ 페이지에서 조회수 10만 이상 레시피 ID만 추출
def get_recipe_ids_over100k(cat4, cat_name):
    ids = []
    page = 1
    prev_ids = set()

    while True:
        url = f"{BASE}/recipe/list.html?cat4={cat4}&order=reco&page={page}"
        soup = get_soup(url)
        cards = soup.select("ul.common_sp_list_ul li")
        if not cards:
            print(f"[{cat_name}] 페이지 없음 — 누적 {len(ids)}개")
            break

        new_ids = []
        for li in cards:
            # recipe_id 추출
            link = li.select_one("a.common_sp_link")
            if not link or "href" not in link.attrs:
                continue
            m = re.search(r"/recipe/(\d+)", link["href"])
            if not m:
                continue
            recipe_id = int(m.group(1))

            # 조회수 텍스트 추출
            views_el = li.select_one("span.common_sp_caption_buyer")
            if not views_el:
                continue
            text = views_el.get_text(strip=True)
            text = text.replace("조회수", "").replace(",", "").replace(" ", "")
            if "만" in text:
                try:
                    views = float(text.replace("만", "")) * 10000
                except:
                    continue
            else:
                try:
                    views = int(re.sub(r"\D", "", text))
                except:
                    continue

            # ✅ 필터링: 조회수 5만 이상
            if views >= 50000:
                new_ids.append(recipe_id)

        ids_set = set(new_ids)
        if not new_ids or ids_set == prev_ids:
            print(f"[{cat_name}] 중단 (page {page}) — 새로운 레시피 없음")
            break

        prev_ids = ids_set
        ids.extend(new_ids)
        print(f"[{cat_name}] page {page} 완료 — 이번 {len(new_ids)}개 / 누적 {len(ids)}개")
        page += 1
        time.sleep(random.uniform(1.0, 2.0))

    return list(dict.fromkeys(ids))

# ✅ 상세 페이지 파서 (이전 버전과 동일)
def parse_recipe(recipe_id, cat4=None):
    url = f"{BASE}/recipe/{recipe_id}"
    try:
        soup = get_soup(url)
    except Exception as e:
        print(f"❌ {recipe_id} 불러오기 실패: {e}")
        return None

    title = soup.select_one("div.view2_summary h3, h3.view2_title")
    title = title.get_text(strip=True) if title else None

    summary_el = soup.select_one("#relationGoods > div.best_tit > b:nth-child(1)")
    summary = summary_el.get_text(strip=True) if summary_el else None

    # 인분
    serving_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info1"
    )
    servings = None
    if serving_el:
        nums = re.findall(r"\d+", serving_el.get_text(strip=True))
        if nums:
            servings = int(nums[0])

    # 조리시간
    time_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info2"
    )
    cook_time = None
    if time_el:
        nums = re.findall(r"\d+", time_el.get_text(strip=True))
        if nums:
            cook_time = int(nums[0])

    # 난이도
    level_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info3"
    )
    level = level_el.get_text(strip=True) if level_el else None

    type_nm = CAT4_MAP.get(cat4, None)

    # 재료
    ingredients = {}
    for li in soup.select(".ready_ingre3 li, .ingre_list li"):
        text = li.get_text(" ", strip=True)
        if not text:
            continue  # 공백, 빈 항목 건너뛰기

        clean_text = text.replace("구매", "").strip()
        parts = clean_text.split()

        # parts가 비었을 경우 대비
        if not parts:
            continue

        name = parts[0]
        amount = " ".join(parts[1:]) if len(parts) > 1 else ""
        ingredients[name] = amount

    # 조리 단계
    steps = []
    for i, el in enumerate(soup.select("#stepDiv .media-body, .view_step_cont"), 1):
        txt = el.get_text(" ", strip=True)
        if txt:
            steps.append(f"{i}. {txt}")

    # 팁
    tips = []
    for i in range(1, len(steps) + 1):
        tip_el = soup.select_one(f"#stepdescr{i} > p")
        tip = tip_el.get_text(strip=True) if tip_el else ""
        tips.append(tip)

    return {
        "RECIPE_ID": recipe_id,
        "RECIPE_NM_KO": title,
        "SUMRY": summary,
        "SERVINGS": servings,
        "TY_NM": type_nm,
        "COOKING_TIME": cook_time,
        "LEVEL_NM": level,
        "INGREDIENT_FULL": json.dumps(ingredients, ensure_ascii=False).replace('"', "'"),
        "STEP_TEXT": json.dumps(steps, ensure_ascii=False),
        "STEP_TIP": json.dumps(tips, ensure_ascii=False),
    }

# ✅ 실행부
if __name__ == "__main__":
    for cat4, cat_name in CAT4_MAP.items():
        print(f"\n🌿 [START] {cat_name} (cat4={cat4}) 수집 시작")
        ids = get_recipe_ids_over100k(cat4, cat_name)
        print(f"[{cat_name}] 조회수 10만 이상 레시피 {len(ids)}개 발견")

        data_list = []
        for rid in ids:
            data = parse_recipe(rid, cat4=cat4)
            if data:
                data_list.append(data)
            time.sleep(random.uniform(1.0, 1.5))

        if data_list:
            df = pd.DataFrame(data_list)
            # 파일명에 사용할 수 없는 문자(예: / \ : * ? " < > |)를 언더스코어로 대체
            safe_cat = re.sub(r'[<>:"/\\|?*]', '_', cat_name)
            filename = f"recipes_over100k2_{safe_cat}.csv"
            out_path = os.path.join(os.getcwd(), filename)
            df.to_csv(out_path, index=False, encoding="utf-8-sig")
            print(f"💾 {cat_name} 완료 — {len(df)}개 저장 → {out_path}")
        else:
            print(f"⚠️ {cat_name}: 수집된 데이터 없음")

        time.sleep(2.0)

    print("\n🎯 전체 cat4 수집 완료 — 모든 조회수 10만 이상 레시피 저장 완료!")
# Out:
# 🌿 [START] 밑반찬 (cat4=63) 수집 시작
# [밑반찬] page 1 완료 — 이번 8개 / 누적 8개
# [밑반찬] page 2 완료 — 이번 10개 / 누적 18개
# [밑반찬] page 3 완료 — 이번 19개 / 누적 37개
# [밑반찬] page 4 완료 — 이번 17개 / 누적 54개
# [밑반찬] page 5 완료 — 이번 21개 / 누적 75개
# [밑반찬] page 6 완료 — 이번 22개 / 누적 97개
# [밑반찬] page 7 완료 — 이번 20개 / 누적 117개
# [밑반찬] page 8 완료 — 이번 12개 / 누적 129개
# [밑반찬] page 9 완료 — 이번 20개 / 누적 149개
# [밑반찬] page 10 완료 — 이번 15개 / 누적 164개
# [밑반찬] page 11 완료 — 이번 17개 / 누적 181개
# [밑반찬] page 12 완료 — 이번 16개 / 누적 197개
# [밑반찬] page 13 완료 — 이번 11개 / 누적 208개
# [밑반찬] page 14 완료 — 이번 22개 / 누적 230개
# [밑반찬] page 15 완료 — 이번 14개 / 누적 244개
# [밑반찬] page 16 완료 — 이번 19개 / 누적 263개
# [밑반찬] page 17 완료 — 이번 13개 / 누적 276개
# [밑반찬] page 18 완료 — 이번 11개 / 누적 287개
# [밑반찬] page 19 완료 — 이번 15개 / 누적 302개
# [밑반찬] page 20 완료 — 이번 12개 / 누적 314개
# [밑반찬] page 21 완료 — 이번 11개 / 누적 325개
# [밑반찬] page 22 완료 — 이번 12개 / 누적 337개
# [밑반찬] page 23 완료 — 이번 12개 / 누적 349개
# [밑반찬] page 24 완료 — 이번 14개 / 누적 363개
# [밑반찬] page 25 완료 — 이번 14개 / 누적 377개
# [밑반찬] page 26 완료 — 이번 6개 / 누적 383개
# [밑반찬] page 27 완료 — 이번 7개 / 누적 390개
# [밑반찬] page 28 완료 — 이번 13개 / 누적 403개
# [밑반찬] page 29 완료 — 이번 8개 / 누적 411개
# [밑반찬] page 30 완료 — 이번 11개 / 누적 422개
# [밑반찬] page 31 완료 — 이번 9개 / 누적 431개
# [밑반찬] page 32 완료 — 이번 6개 / 누적 437개
# [밑반찬] page 33 완료 — 이번 5개 / 누적 442개
# [밑반찬] page 34 완료 — 이번 9개 / 누적 451개
# [밑반찬] page 35 완료 — 이번 5개 / 누적 456개
# [밑반찬] page 36 완료 — 이번 12개 / 누적 468개
# [밑반찬] page 37 완료 — 이번 10개 / 누적 478개
# [밑반찬] page 38 완료 — 이번 6개 / 누적 484개
# [밑반찬] page 39 완료 — 이번 11개 / 누적 495개
# [밑반찬] page 40 완료 — 이번 8개 / 누적 503개
# [밑반찬] page 41 완료 — 이번 7개 / 누적 510개
# [밑반찬] page 42 완료 — 이번 11개 / 누적 521개
# [밑반찬] page 43 완료 — 이번 8개 / 누적 529개
# [밑반찬] page 44 완료 — 이번 4개 / 누적 533개
# [밑반찬] page 45 완료 — 이번 13개 / 누적 546개
# [밑반찬] page 46 완료 — 이번 4개 / 누적 550개
# [밑반찬] page 47 완료 — 이번 6개 / 누적 556개
# [밑반찬] page 48 완료 — 이번 13개 / 누적 569개
# [밑반찬] page 49 완료 — 이번 9개 / 누적 578개
# [밑반찬] page 50 완료 — 이번 8개 / 누적 586개
# [밑반찬] page 51 완료 — 이번 6개 / 누적 592개
# [밑반찬] page 52 완료 — 이번 12개 / 누적 604개
# [밑반찬] page 53 완료 — 이번 3개 / 누적 607개
# [밑반찬] page 54 완료 — 이번 5개 / 누적 612개
# [밑반찬] page 55 완료 — 이번 5개 / 누적 617개
# [밑반찬] page 56 완료 — 이번 11개 / 누적 628개
# [밑반찬] page 57 완료 — 이번 6개 / 누적 634개
# [밑반찬] page 58 완료 — 이번 8개 / 누적 642개
# [밑반찬] page 59 완료 — 이번 5개 / 누적 647개
# [밑반찬] page 60 완료 — 이번 7개 / 누적 654개
# [밑반찬] page 61 완료 — 이번 5개 / 누적 659개
# [밑반찬] page 62 완료 — 이번 10개 / 누적 669개
# [밑반찬] page 63 완료 — 이번 7개 / 누적 676개
# [밑반찬] page 64 완료 — 이번 8개 / 누적 684개
# [밑반찬] page 65 완료 — 이번 4개 / 누적 688개
# [밑반찬] page 66 완료 — 이번 6개 / 누적 694개
# [밑반찬] page 67 완료 — 이번 6개 / 누적 700개
# [밑반찬] page 68 완료 — 이번 4개 / 누적 704개
# [밑반찬] page 69 완료 — 이번 7개 / 누적 711개
# [밑반찬] page 70 완료 — 이번 6개 / 누적 717개
# [밑반찬] page 71 완료 — 이번 7개 / 누적 724개
# [밑반찬] page 72 완료 — 이번 7개 / 누적 731개
# [밑반찬] page 73 완료 — 이번 4개 / 누적 735개
# [밑반찬] page 74 완료 — 이번 3개 / 누적 738개
# [밑반찬] page 75 완료 — 이번 1개 / 누적 739개
# [밑반찬] page 76 완료 — 이번 6개 / 누적 745개
# [밑반찬] page 77 완료 — 이번 11개 / 누적 756개
# [밑반찬] page 78 완료 — 이번 4개 / 누적 760개
# [밑반찬] page 79 완료 — 이번 6개 / 누적 766개
# [밑반찬] page 80 완료 — 이번 8개 / 누적 774개
# [밑반찬] page 81 완료 — 이번 10개 / 누적 784개
# [밑반찬] page 82 완료 — 이번 6개 / 누적 790개
# [밑반찬] page 83 완료 — 이번 8개 / 누적 798개
# [밑반찬] page 84 완료 — 이번 6개 / 누적 804개
# [밑반찬] page 85 완료 — 이번 5개 / 누적 809개
# [밑반찬] page 86 완료 — 이번 5개 / 누적 814개
# [밑반찬] page 87 완료 — 이번 8개 / 누적 822개
# [밑반찬] page 88 완료 — 이번 8개 / 누적 830개
# [밑반찬] page 89 완료 — 이번 4개 / 누적 834개
# [밑반찬] page 90 완료 — 이번 3개 / 누적 837개
# [밑반찬] page 91 완료 — 이번 5개 / 누적 842개
# [밑반찬] page 92 완료 — 이번 4개 / 누적 846개
# [밑반찬] page 93 완료 — 이번 4개 / 누적 850개
# [밑반찬] page 94 완료 — 이번 7개 / 누적 857개
# [밑반찬] page 95 완료 — 이번 8개 / 누적 865개
# [밑반찬] page 96 완료 — 이번 6개 / 누적 871개
# [밑반찬] page 97 완료 — 이번 4개 / 누적 875개
# [밑반찬] page 98 완료 — 이번 4개 / 누적 879개
# [밑반찬] page 99 완료 — 이번 3개 / 누적 882개
# [밑반찬] page 100 완료 — 이번 6개 / 누적 888개
# [밑반찬] page 101 완료 — 이번 9개 / 누적 897개
# [밑반찬] page 102 완료 — 이번 7개 / 누적 904개
# [밑반찬] page 103 완료 — 이번 3개 / 누적 907개
# [밑반찬] page 104 완료 — 이번 8개 / 누적 915개
# [밑반찬] page 105 완료 — 이번 6개 / 누적 921개
# [밑반찬] page 106 완료 — 이번 3개 / 누적 924개
# [밑반찬] page 107 완료 — 이번 8개 / 누적 932개
# [밑반찬] page 108 완료 — 이번 2개 / 누적 934개
# [밑반찬] page 109 완료 — 이번 2개 / 누적 936개
# [밑반찬] page 110 완료 — 이번 4개 / 누적 940개
# [밑반찬] page 111 완료 — 이번 3개 / 누적 943개
# [밑반찬] page 112 완료 — 이번 3개 / 누적 946개
# [밑반찬] page 113 완료 — 이번 7개 / 누적 953개
# [밑반찬] page 114 완료 — 이번 5개 / 누적 958개
# [밑반찬] page 115 완료 — 이번 4개 / 누적 962개
# [밑반찬] page 116 완료 — 이번 4개 / 누적 966개
# [밑반찬] page 117 완료 — 이번 2개 / 누적 968개
# [밑반찬] page 118 완료 — 이번 7개 / 누적 975개
# [밑반찬] page 119 완료 — 이번 5개 / 누적 980개
# [밑반찬] page 120 완료 — 이번 8개 / 누적 988개
# [밑반찬] page 121 완료 — 이번 5개 / 누적 993개
# [밑반찬] page 122 완료 — 이번 5개 / 누적 998개
# [밑반찬] page 123 완료 — 이번 4개 / 누적 1002개
# [밑반찬] page 124 완료 — 이번 4개 / 누적 1006개
# [밑반찬] page 125 완료 — 이번 4개 / 누적 1010개
# [밑반찬] page 126 완료 — 이번 3개 / 누적 1013개
# [밑반찬] page 127 완료 — 이번 6개 / 누적 1019개
# [밑반찬] page 128 완료 — 이번 7개 / 누적 1026개
# [밑반찬] page 129 완료 — 이번 5개 / 누적 1031개
# [밑반찬] page 130 완료 — 이번 3개 / 누적 1034개
# [밑반찬] page 131 완료 — 이번 4개 / 누적 1038개
# [밑반찬] page 132 완료 — 이번 4개 / 누적 1042개
# [밑반찬] page 133 완료 — 이번 5개 / 누적 1047개
# [밑반찬] page 134 완료 — 이번 7개 / 누적 1054개
# [밑반찬] page 135 완료 — 이번 7개 / 누적 1061개
# [밑반찬] page 136 완료 — 이번 4개 / 누적 1065개
# [밑반찬] page 137 완료 — 이번 5개 / 누적 1070개
# [밑반찬] page 138 완료 — 이번 5개 / 누적 1075개
# [밑반찬] page 139 완료 — 이번 4개 / 누적 1079개
# [밑반찬] page 140 완료 — 이번 5개 / 누적 1084개
# [밑반찬] page 141 완료 — 이번 2개 / 누적 1086개
# [밑반찬] page 142 완료 — 이번 6개 / 누적 1092개
# [밑반찬] page 143 완료 — 이번 8개 / 누적 1100개
# [밑반찬] page 144 완료 — 이번 2개 / 누적 1102개
# [밑반찬] page 145 완료 — 이번 3개 / 누적 1105개
# [밑반찬] page 146 완료 — 이번 8개 / 누적 1113개
# [밑반찬] page 147 완료 — 이번 7개 / 누적 1120개
# [밑반찬] page 148 완료 — 이번 6개 / 누적 1126개
# [밑반찬] page 149 완료 — 이번 4개 / 누적 1130개
# [밑반찬] page 150 완료 — 이번 5개 / 누적 1135개
# [밑반찬] page 151 완료 — 이번 6개 / 누적 1141개
# [밑반찬] page 152 완료 — 이번 3개 / 누적 1144개
# [밑반찬] page 153 완료 — 이번 5개 / 누적 1149개
# [밑반찬] page 154 완료 — 이번 4개 / 누적 1153개
# [밑반찬] page 155 완료 — 이번 4개 / 누적 1157개
# [밑반찬] page 156 완료 — 이번 5개 / 누적 1162개
# [밑반찬] page 157 완료 — 이번 3개 / 누적 1165개
# [밑반찬] page 158 완료 — 이번 4개 / 누적 1169개
# [밑반찬] page 159 완료 — 이번 4개 / 누적 1173개
# [밑반찬] page 160 완료 — 이번 5개 / 누적 1178개
# [밑반찬] page 161 완료 — 이번 2개 / 누적 1180개
# [밑반찬] page 162 완료 — 이번 2개 / 누적 1182개
# [밑반찬] page 163 완료 — 이번 3개 / 누적 1185개
# [밑반찬] page 164 완료 — 이번 4개 / 누적 1189개
# [밑반찬] page 165 완료 — 이번 6개 / 누적 1195개
# [밑반찬] page 166 완료 — 이번 4개 / 누적 1199개
# [밑반찬] page 167 완료 — 이번 1개 / 누적 1200개
# [밑반찬] page 168 완료 — 이번 3개 / 누적 1203개
# [밑반찬] page 169 완료 — 이번 7개 / 누적 1210개
# [밑반찬] page 170 완료 — 이번 5개 / 누적 1215개
# [밑반찬] page 171 완료 — 이번 6개 / 누적 1221개
# [밑반찬] page 172 완료 — 이번 5개 / 누적 1226개
# [밑반찬] page 173 완료 — 이번 3개 / 누적 1229개
# [밑반찬] page 174 완료 — 이번 6개 / 누적 1235개
# [밑반찬] page 175 완료 — 이번 6개 / 누적 1241개
# [밑반찬] page 176 완료 — 이번 5개 / 누적 1246개
# [밑반찬] page 177 완료 — 이번 6개 / 누적 1252개
# [밑반찬] page 178 완료 — 이번 2개 / 누적 1254개
# [밑반찬] page 179 완료 — 이번 3개 / 누적 1257개
# [밑반찬] page 180 완료 — 이번 1개 / 누적 1258개
# [밑반찬] page 181 완료 — 이번 5개 / 누적 1263개
# [밑반찬] page 182 완료 — 이번 4개 / 누적 1267개
# [밑반찬] page 183 완료 — 이번 1개 / 누적 1268개
# [밑반찬] page 184 완료 — 이번 6개 / 누적 1274개
# [밑반찬] page 185 완료 — 이번 2개 / 누적 1276개
# [밑반찬] page 186 완료 — 이번 2개 / 누적 1278개
# [밑반찬] page 187 완료 — 이번 2개 / 누적 1280개
# [밑반찬] page 188 완료 — 이번 2개 / 누적 1282개
# [밑반찬] page 189 완료 — 이번 6개 / 누적 1288개
# [밑반찬] page 190 완료 — 이번 2개 / 누적 1290개
# [밑반찬] page 191 완료 — 이번 2개 / 누적 1292개
# [밑반찬] page 192 완료 — 이번 4개 / 누적 1296개
# [밑반찬] 중단 (page 193) — 새로운 레시피 없음
# [밑반찬] 조회수 10만 이상 레시피 1296개 발견
# ❌ 6869205 불러오기 실패: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 183
#     181     if data:
#     182         data_list.append(data)
# --> 183     time.sleep(random.uniform(1.0, 1.5))
#     185 if data_list:
#     186     df = pd.DataFrame(data_list)
#
# KeyboardInterrupt:

# %%
# !pip install selenium
# !pip install beautifulsoup4
# !pip install pandas
# !pip install lxml
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.11/site-packages (4.37.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.31.0 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (0.31.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (3.4)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.11/site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.14.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.11/site-packages (4.9.3)

# %%
import re, json, time, random, os
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# ✅ 기본 설정
BASE = "https://www.10000recipe.com"

CAT4_MAP = {
    63: "밑반찬", 56: "메인반찬", 54: "국/탕", 55: "찌개",
    53: "면/만두", 52: "밥/죽/떡", 61: "퓨전", 65: "양식",
    64: "샐러드", 68: "스프", 62: "기타"
}

# ✅ Chrome 설정
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=chrome_options)

def get_soup(url):
    """Selenium 기반 BeautifulSoup 파서"""
    driver.get(url)
    time.sleep(random.uniform(1.8, 2.8))  # JS 로딩 대기
    html = driver.page_source
    return BeautifulSoup(html, "html.parser")

# ✅ 조회수 5만 이상 레시피 ID 추출
def get_recipe_ids_over100k(cat4, cat_name):
    ids = []
    page = 1
    prev_ids = set()

    while True:
        url = f"{BASE}/recipe/list.html?cat4={cat4}&order=reco&page={page}"
        soup = get_soup(url)
        cards = soup.select("ul.common_sp_list_ul li")

        if not cards:
            print(f"[{cat_name}] 페이지 없음 — 누적 {len(ids)}개")
            break

        new_ids = []
        for li in cards:
            link = li.select_one("a.common_sp_link")
            if not link or "href" not in link.attrs:
                continue

            m = re.search(r"/recipe/(\d+)", link["href"])
            if not m:
                continue
            recipe_id = int(m.group(1))

            # ✅ 조회수 추출
            views_el = li.select_one("span.common_sp_caption_buyer")
            if not views_el:
                continue
            text = views_el.get_text(strip=True)
            text = text.replace("조회수", "").replace(",", "").replace(" ", "")
            if "만" in text:
                try:
                    views = float(text.replace("만", "")) * 10000
                except:
                    continue
            else:
                try:
                    views = int(re.sub(r"\D", "", text))
                except:
                    continue

            if views >= 50000:
                new_ids.append(recipe_id)

        ids_set = set(new_ids)
        if not new_ids or ids_set == prev_ids:
            print(f"[{cat_name}] 중단 (page {page}) — 새로운 레시피 없음")
            break

        prev_ids = ids_set
        ids.extend(new_ids)
        print(f"[{cat_name}] page {page} 완료 — 이번 {len(new_ids)}개 / 누적 {len(ids)}개")
        page += 1
        time.sleep(random.uniform(1.2, 2.2))

    return list(dict.fromkeys(ids))

# ✅ 레시피 상세 파서
def parse_recipe(recipe_id, cat4=None):
    url = f"{BASE}/recipe/{recipe_id}"
    try:
        soup = get_soup(url)
    except Exception as e:
        print(f"❌ {recipe_id} 불러오기 실패: {e}")
        return None

    title = soup.select_one("div.view2_summary h3, h3.view2_title")
    title = title.get_text(strip=True) if title else None

    summary_el = soup.select_one("#relationGoods > div.best_tit > b:nth-child(1)")
    summary = summary_el.get_text(strip=True) if summary_el else None

    # 인분
    serving_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info1"
    )
    servings = None
    if serving_el:
        nums = re.findall(r"\d+", serving_el.get_text(strip=True))
        if nums:
            servings = int(nums[0])

    # 조리시간
    time_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info2"
    )
    cook_time = None
    if time_el:
        nums = re.findall(r"\d+", time_el.get_text(strip=True))
        if nums:
            cook_time = int(nums[0])

    # 난이도
    level_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info3"
    )
    level = level_el.get_text(strip=True) if level_el else None

    type_nm = CAT4_MAP.get(cat4, None)

    # 재료
    ingredients = {}
    for li in soup.select(".ready_ingre3 li, .ingre_list li"):
        text = li.get_text(" ", strip=True)
        if not text:
            continue
        clean_text = text.replace("구매", "").strip()
        parts = clean_text.split()
        if not parts:
            continue
        name = parts[0]
        amount = " ".join(parts[1:]) if len(parts) > 1 else ""
        ingredients[name] = amount

    # 조리 단계
    steps = []
    for i, el in enumerate(soup.select("#stepDiv .media-body, .view_step_cont"), 1):
        txt = el.get_text(" ", strip=True)
        if txt:
            steps.append(f"{i}. {txt}")

    # 팁
    tips = []
    for i in range(1, len(steps) + 1):
        tip_el = soup.select_one(f"#stepdescr{i} > p")
        tip = tip_el.get_text(strip=True) if tip_el else ""
        tips.append(tip)

    return {
        "RECIPE_ID": recipe_id,
        "RECIPE_NM_KO": title,
        "SUMRY": summary,
        "SERVINGS": servings,
        "TY_NM": type_nm,
        "COOKING_TIME": cook_time,
        "LEVEL_NM": level,
        "INGREDIENT_FULL": json.dumps(ingredients, ensure_ascii=False).replace('"', "'"),
        "STEP_TEXT": json.dumps(steps, ensure_ascii=False),
        "STEP_TIP": json.dumps(tips, ensure_ascii=False),
    }

# ✅ 실행부
if __name__ == "__main__":
    for cat4, cat_name in CAT4_MAP.items():
        print(f"\n🌿 [START] {cat_name} (cat4={cat4}) 수집 시작")
        ids = get_recipe_ids_over100k(cat4, cat_name)
        print(f"[{cat_name}] 조회수 10만 이상 레시피 {len(ids)}개 발견")

        data_list = []
        for rid in ids:
            data = parse_recipe(rid, cat4=cat4)
            if data:
                data_list.append(data)
            time.sleep(random.uniform(1.2, 2.0))

        if data_list:
            df = pd.DataFrame(data_list)
            safe_cat = re.sub(r'[<>:"/\\|?*]', '_', cat_name)
            filename = f"recipes_over100k2_{safe_cat}.csv"
            out_path = os.path.join(os.getcwd(), filename)
            df.to_csv(out_path, index=False, encoding="utf-8-sig")
            print(f"💾 {cat_name} 완료 — {len(df)}개 저장 → {out_path}")
        else:
            print(f"⚠️ {cat_name}: 수집된 데이터 없음")

        time.sleep(2.5)

    driver.quit()
    print("\n🎯 전체 cat4 수집 완료 — 모든 조회수 10만 이상 레시피 저장 완료!")
# Out:
# 🌿 [START] 밑반찬 (cat4=63) 수집 시작
# [밑반찬] page 1 완료 — 이번 8개 / 누적 8개
# [밑반찬] page 2 완료 — 이번 10개 / 누적 18개
# [밑반찬] page 3 완료 — 이번 19개 / 누적 37개
# [밑반찬] page 4 완료 — 이번 17개 / 누적 54개
# [밑반찬] page 5 완료 — 이번 21개 / 누적 75개
# [밑반찬] page 6 완료 — 이번 22개 / 누적 97개
# [밑반찬] page 7 완료 — 이번 20개 / 누적 117개
# [밑반찬] page 8 완료 — 이번 12개 / 누적 129개
# [밑반찬] page 9 완료 — 이번 20개 / 누적 149개
# [밑반찬] page 10 완료 — 이번 15개 / 누적 164개
# [밑반찬] page 11 완료 — 이번 17개 / 누적 181개
# [밑반찬] page 12 완료 — 이번 16개 / 누적 197개
# [밑반찬] page 13 완료 — 이번 11개 / 누적 208개
# [밑반찬] page 14 완료 — 이번 22개 / 누적 230개
# [밑반찬] page 15 완료 — 이번 15개 / 누적 245개
# [밑반찬] page 16 완료 — 이번 18개 / 누적 263개
# [밑반찬] page 17 완료 — 이번 13개 / 누적 276개
# [밑반찬] page 18 완료 — 이번 11개 / 누적 287개
# [밑반찬] page 19 완료 — 이번 15개 / 누적 302개
# [밑반찬] page 20 완료 — 이번 12개 / 누적 314개
# [밑반찬] page 21 완료 — 이번 11개 / 누적 325개
# [밑반찬] page 22 완료 — 이번 12개 / 누적 337개
# [밑반찬] page 23 완료 — 이번 12개 / 누적 349개
# [밑반찬] page 24 완료 — 이번 14개 / 누적 363개
# [밑반찬] page 25 완료 — 이번 14개 / 누적 377개
# [밑반찬] page 26 완료 — 이번 6개 / 누적 383개
# [밑반찬] page 27 완료 — 이번 7개 / 누적 390개
# [밑반찬] page 28 완료 — 이번 12개 / 누적 402개
# [밑반찬] page 29 완료 — 이번 10개 / 누적 412개
# [밑반찬] page 30 완료 — 이번 10개 / 누적 422개
# [밑반찬] page 31 완료 — 이번 9개 / 누적 431개
# [밑반찬] page 32 완료 — 이번 6개 / 누적 437개
# [밑반찬] page 33 완료 — 이번 5개 / 누적 442개
# [밑반찬] page 34 완료 — 이번 9개 / 누적 451개
# [밑반찬] page 35 완료 — 이번 5개 / 누적 456개
# [밑반찬] page 36 완료 — 이번 12개 / 누적 468개
# [밑반찬] page 37 완료 — 이번 10개 / 누적 478개
# [밑반찬] page 38 완료 — 이번 6개 / 누적 484개
# [밑반찬] page 39 완료 — 이번 11개 / 누적 495개
# [밑반찬] page 40 완료 — 이번 8개 / 누적 503개
# [밑반찬] page 41 완료 — 이번 6개 / 누적 509개
# [밑반찬] page 42 완료 — 이번 12개 / 누적 521개
# [밑반찬] page 43 완료 — 이번 8개 / 누적 529개
# [밑반찬] page 44 완료 — 이번 4개 / 누적 533개
# [밑반찬] page 45 완료 — 이번 13개 / 누적 546개
# [밑반찬] page 46 완료 — 이번 5개 / 누적 551개
# [밑반찬] page 47 완료 — 이번 5개 / 누적 556개
# [밑반찬] page 48 완료 — 이번 13개 / 누적 569개
# [밑반찬] page 49 완료 — 이번 9개 / 누적 578개
# [밑반찬] page 50 완료 — 이번 8개 / 누적 586개
# [밑반찬] page 51 완료 — 이번 5개 / 누적 591개
# [밑반찬] page 52 완료 — 이번 13개 / 누적 604개
# [밑반찬] page 53 완료 — 이번 3개 / 누적 607개
# [밑반찬] page 54 완료 — 이번 5개 / 누적 612개
# [밑반찬] page 55 완료 — 이번 5개 / 누적 617개
# [밑반찬] page 56 완료 — 이번 11개 / 누적 628개
# [밑반찬] page 57 완료 — 이번 6개 / 누적 634개
# [밑반찬] page 58 완료 — 이번 8개 / 누적 642개
# [밑반찬] page 59 완료 — 이번 5개 / 누적 647개
# [밑반찬] page 60 완료 — 이번 7개 / 누적 654개
# [밑반찬] page 61 완료 — 이번 5개 / 누적 659개
# [밑반찬] page 62 완료 — 이번 10개 / 누적 669개
# [밑반찬] page 63 완료 — 이번 7개 / 누적 676개
# [밑반찬] page 64 완료 — 이번 8개 / 누적 684개
# [밑반찬] page 65 완료 — 이번 4개 / 누적 688개
# [밑반찬] page 66 완료 — 이번 6개 / 누적 694개
# [밑반찬] page 67 완료 — 이번 6개 / 누적 700개
# [밑반찬] page 68 완료 — 이번 4개 / 누적 704개
# [밑반찬] page 69 완료 — 이번 7개 / 누적 711개
# [밑반찬] page 70 완료 — 이번 6개 / 누적 717개
# [밑반찬] page 71 완료 — 이번 8개 / 누적 725개
# [밑반찬] page 72 완료 — 이번 6개 / 누적 731개
# [밑반찬] page 73 완료 — 이번 4개 / 누적 735개
# [밑반찬] page 74 완료 — 이번 3개 / 누적 738개
# [밑반찬] page 75 완료 — 이번 1개 / 누적 739개
# [밑반찬] page 76 완료 — 이번 6개 / 누적 745개
# [밑반찬] page 77 완료 — 이번 11개 / 누적 756개
# [밑반찬] page 78 완료 — 이번 4개 / 누적 760개
# [밑반찬] page 79 완료 — 이번 6개 / 누적 766개
# [밑반찬] page 80 완료 — 이번 8개 / 누적 774개
# [밑반찬] page 81 완료 — 이번 10개 / 누적 784개
# [밑반찬] page 82 완료 — 이번 6개 / 누적 790개
# [밑반찬] page 83 완료 — 이번 8개 / 누적 798개
# [밑반찬] page 84 완료 — 이번 6개 / 누적 804개
# [밑반찬] page 85 완료 — 이번 5개 / 누적 809개
# [밑반찬] page 86 완료 — 이번 6개 / 누적 815개
# [밑반찬] page 87 완료 — 이번 7개 / 누적 822개
# [밑반찬] page 88 완료 — 이번 8개 / 누적 830개
# [밑반찬] page 89 완료 — 이번 4개 / 누적 834개
# [밑반찬] page 90 완료 — 이번 4개 / 누적 838개
# [밑반찬] page 91 완료 — 이번 4개 / 누적 842개
# [밑반찬] page 92 완료 — 이번 4개 / 누적 846개
# [밑반찬] page 93 완료 — 이번 4개 / 누적 850개
# [밑반찬] page 94 완료 — 이번 7개 / 누적 857개
# [밑반찬] page 95 완료 — 이번 8개 / 누적 865개
# [밑반찬] page 96 완료 — 이번 6개 / 누적 871개
# [밑반찬] page 97 완료 — 이번 4개 / 누적 875개
# [밑반찬] page 98 완료 — 이번 4개 / 누적 879개
# [밑반찬] page 99 완료 — 이번 3개 / 누적 882개
# [밑반찬] page 100 완료 — 이번 6개 / 누적 888개
# [밑반찬] page 101 완료 — 이번 9개 / 누적 897개
# [밑반찬] page 102 완료 — 이번 7개 / 누적 904개
# [밑반찬] page 103 완료 — 이번 3개 / 누적 907개
# [밑반찬] page 104 완료 — 이번 8개 / 누적 915개
# [밑반찬] page 105 완료 — 이번 6개 / 누적 921개
# [밑반찬] page 106 완료 — 이번 3개 / 누적 924개
# [밑반찬] page 107 완료 — 이번 8개 / 누적 932개
# [밑반찬] page 108 완료 — 이번 2개 / 누적 934개
# [밑반찬] page 109 완료 — 이번 2개 / 누적 936개
# [밑반찬] page 110 완료 — 이번 4개 / 누적 940개
# [밑반찬] page 111 완료 — 이번 3개 / 누적 943개
# [밑반찬] page 112 완료 — 이번 3개 / 누적 946개
# [밑반찬] page 113 완료 — 이번 7개 / 누적 953개
# [밑반찬] page 114 완료 — 이번 4개 / 누적 957개
# [밑반찬] page 115 완료 — 이번 5개 / 누적 962개
# [밑반찬] page 116 완료 — 이번 4개 / 누적 966개
# [밑반찬] page 117 완료 — 이번 3개 / 누적 969개
# [밑반찬] page 118 완료 — 이번 6개 / 누적 975개
# [밑반찬] page 119 완료 — 이번 5개 / 누적 980개
# [밑반찬] page 120 완료 — 이번 8개 / 누적 988개
# [밑반찬] page 121 완료 — 이번 5개 / 누적 993개
# [밑반찬] page 122 완료 — 이번 5개 / 누적 998개
# [밑반찬] page 123 완료 — 이번 3개 / 누적 1001개
# [밑반찬] page 124 완료 — 이번 5개 / 누적 1006개
# [밑반찬] page 125 완료 — 이번 4개 / 누적 1010개
# [밑반찬] page 126 완료 — 이번 4개 / 누적 1014개
# [밑반찬] page 127 완료 — 이번 5개 / 누적 1019개
# [밑반찬] page 128 완료 — 이번 7개 / 누적 1026개
# [밑반찬] page 129 완료 — 이번 5개 / 누적 1031개
# [밑반찬] page 130 완료 — 이번 3개 / 누적 1034개
# [밑반찬] page 131 완료 — 이번 4개 / 누적 1038개
# [밑반찬] page 132 완료 — 이번 4개 / 누적 1042개
# [밑반찬] page 133 완료 — 이번 5개 / 누적 1047개
# [밑반찬] page 134 완료 — 이번 8개 / 누적 1055개
# [밑반찬] page 135 완료 — 이번 6개 / 누적 1061개
# [밑반찬] page 136 완료 — 이번 4개 / 누적 1065개
# [밑반찬] page 137 완료 — 이번 5개 / 누적 1070개
# [밑반찬] page 138 완료 — 이번 5개 / 누적 1075개
# [밑반찬] page 139 완료 — 이번 4개 / 누적 1079개
# [밑반찬] page 140 완료 — 이번 5개 / 누적 1084개
# [밑반찬] page 141 완료 — 이번 2개 / 누적 1086개
# [밑반찬] page 142 완료 — 이번 6개 / 누적 1092개
# [밑반찬] page 143 완료 — 이번 8개 / 누적 1100개
# [밑반찬] page 144 완료 — 이번 2개 / 누적 1102개
# [밑반찬] page 145 완료 — 이번 3개 / 누적 1105개
# [밑반찬] page 146 완료 — 이번 8개 / 누적 1113개
# [밑반찬] page 147 완료 — 이번 7개 / 누적 1120개
# [밑반찬] page 148 완료 — 이번 6개 / 누적 1126개
# [밑반찬] page 149 완료 — 이번 3개 / 누적 1129개
# [밑반찬] page 150 완료 — 이번 6개 / 누적 1135개
# [밑반찬] page 151 완료 — 이번 5개 / 누적 1140개
# [밑반찬] page 152 완료 — 이번 3개 / 누적 1143개
# [밑반찬] page 153 완료 — 이번 6개 / 누적 1149개
# [밑반찬] page 154 완료 — 이번 4개 / 누적 1153개
# [밑반찬] page 155 완료 — 이번 4개 / 누적 1157개
# [밑반찬] page 156 완료 — 이번 5개 / 누적 1162개
# [밑반찬] page 157 완료 — 이번 3개 / 누적 1165개
# [밑반찬] page 158 완료 — 이번 4개 / 누적 1169개
# [밑반찬] page 159 완료 — 이번 4개 / 누적 1173개
# [밑반찬] page 160 완료 — 이번 5개 / 누적 1178개
# [밑반찬] page 161 완료 — 이번 2개 / 누적 1180개
# [밑반찬] page 162 완료 — 이번 2개 / 누적 1182개
# [밑반찬] page 163 완료 — 이번 3개 / 누적 1185개
# [밑반찬] page 164 완료 — 이번 5개 / 누적 1190개
# [밑반찬] page 165 완료 — 이번 5개 / 누적 1195개
# [밑반찬] page 166 완료 — 이번 4개 / 누적 1199개
# [밑반찬] page 167 완료 — 이번 1개 / 누적 1200개
# [밑반찬] page 168 완료 — 이번 3개 / 누적 1203개
# [밑반찬] page 169 완료 — 이번 7개 / 누적 1210개
# [밑반찬] page 170 완료 — 이번 6개 / 누적 1216개
# [밑반찬] page 171 완료 — 이번 4개 / 누적 1220개
# [밑반찬] page 172 완료 — 이번 6개 / 누적 1226개
# [밑반찬] page 173 완료 — 이번 3개 / 누적 1229개
# [밑반찬] page 174 완료 — 이번 6개 / 누적 1235개
# [밑반찬] page 175 완료 — 이번 6개 / 누적 1241개
# [밑반찬] page 176 완료 — 이번 5개 / 누적 1246개
# [밑반찬] page 177 완료 — 이번 6개 / 누적 1252개
# [밑반찬] page 178 완료 — 이번 2개 / 누적 1254개
# [밑반찬] page 179 완료 — 이번 3개 / 누적 1257개
# [밑반찬] page 180 완료 — 이번 1개 / 누적 1258개
# [밑반찬] page 181 완료 — 이번 5개 / 누적 1263개
# [밑반찬] page 182 완료 — 이번 4개 / 누적 1267개
# [밑반찬] page 183 완료 — 이번 1개 / 누적 1268개
# [밑반찬] page 184 완료 — 이번 5개 / 누적 1273개
# [밑반찬] page 185 완료 — 이번 3개 / 누적 1276개
# [밑반찬] page 186 완료 — 이번 2개 / 누적 1278개
# [밑반찬] page 187 완료 — 이번 2개 / 누적 1280개
# [밑반찬] page 188 완료 — 이번 2개 / 누적 1282개
# [밑반찬] page 189 완료 — 이번 5개 / 누적 1287개
# [밑반찬] page 190 완료 — 이번 3개 / 누적 1290개
# [밑반찬] page 191 완료 — 이번 2개 / 누적 1292개
# [밑반찬] page 192 완료 — 이번 4개 / 누적 1296개
# [밑반찬] 중단 (page 193) — 새로운 레시피 없음
# [밑반찬] 조회수 10만 이상 레시피 1296개 발견
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 186
#     184     if data:
#     185         data_list.append(data)
# --> 186     time.sleep(random.uniform(1.2, 2.0))
#     188 if data_list:
#     189     df = pd.DataFrame(data_list)
#
# KeyboardInterrupt:

# %%
from bs4 import BeautifulSoup
print("BeautifulSoup import 성공!")
# Out:
# BeautifulSoup import 성공!
