# %%
import re, requests, json, time, random
from bs4 import BeautifulSoup
import pandas as pd
import os

BASE = "https://www.10000recipe.com"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# ✅ cat4 분류
CAT4_MAP = {
    54: "국/탕", 55: "찌개",
    53: "면/만두", 52: "밥/죽/떡", 61: "퓨전", 65: "양식", 64: "샐러드", 68: "스프", 62: "기타"
}

# ✅ 공통 파서
def get_soup(url):
    r = requests.get(url, headers=HEADERS, timeout=15)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")

# ✅ 페이지에서 조회수 10만 이상 레시피 ID만 추출
def get_recipe_ids_over100k(cat4, cat_name):
    ids = []
    page = 1
    prev_ids = set()

    while True:
        url = f"{BASE}/recipe/list.html?cat4={cat4}&order=reco&page={page}"
        soup = get_soup(url)
        cards = soup.select("ul.common_sp_list_ul li")
        if not cards:
            print(f"[{cat_name}] 페이지 없음 — 누적 {len(ids)}개")
            break

        new_ids = []
        for li in cards:
            # recipe_id 추출
            link = li.select_one("a.common_sp_link")
            if not link or "href" not in link.attrs:
                continue
            m = re.search(r"/recipe/(\d+)", link["href"])
            if not m:
                continue
            recipe_id = int(m.group(1))

            # 조회수 텍스트 추출
            views_el = li.select_one("span.common_sp_caption_buyer")
            if not views_el:
                continue
            text = views_el.get_text(strip=True)
            text = text.replace("조회수", "").replace(",", "").replace(" ", "")
            if "만" in text:
                try:
                    views = float(text.replace("만", "")) * 10000
                except:
                    continue
            else:
                try:
                    views = int(re.sub(r"\D", "", text))
                except:
                    continue

            # ✅ 필터링: 조회수 10만 이상
            if views >= 100000:
                new_ids.append(recipe_id)

        ids_set = set(new_ids)
        if not new_ids or ids_set == prev_ids:
            print(f"[{cat_name}] 중단 (page {page}) — 새로운 레시피 없음")
            break

        prev_ids = ids_set
        ids.extend(new_ids)
        print(f"[{cat_name}] page {page} 완료 — 이번 {len(new_ids)}개 / 누적 {len(ids)}개")
        page += 1
        time.sleep(random.uniform(1.0, 2.0))

    return list(dict.fromkeys(ids))

# ✅ 상세 페이지 파서 (이전 버전과 동일)
def parse_recipe(recipe_id, cat4=None):
    url = f"{BASE}/recipe/{recipe_id}"
    try:
        soup = get_soup(url)
    except Exception as e:
        print(f"❌ {recipe_id} 불러오기 실패: {e}")
        return None

    title = soup.select_one("div.view2_summary h3, h3.view2_title")
    title = title.get_text(strip=True) if title else None

    summary_el = soup.select_one("#relationGoods > div.best_tit > b:nth-child(1)")
    summary = summary_el.get_text(strip=True) if summary_el else None

    # 인분
    serving_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info1"
    )
    servings = None
    if serving_el:
        nums = re.findall(r"\d+", serving_el.get_text(strip=True))
        if nums:
            servings = int(nums[0])

    # 조리시간
    time_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info2"
    )
    cook_time = None
    if time_el:
        nums = re.findall(r"\d+", time_el.get_text(strip=True))
        if nums:
            cook_time = int(nums[0])

    # 난이도
    level_el = soup.select_one(
        "#contents_area_full div.view2_summary_info span.view2_summary_info3"
    )
    level = level_el.get_text(strip=True) if level_el else None

    type_nm = CAT4_MAP.get(cat4, None)

    # 재료
    ingredients = {}
    for li in soup.select(".ready_ingre3 li, .ingre_list li"):
        text = li.get_text(" ", strip=True)
        if not text:
            continue  # 공백, 빈 항목 건너뛰기

        clean_text = text.replace("구매", "").strip()
        parts = clean_text.split()

        # parts가 비었을 경우 대비
        if not parts:
            continue

        name = parts[0]
        amount = " ".join(parts[1:]) if len(parts) > 1 else ""
        ingredients[name] = amount

    # 조리 단계
    steps = []
    for i, el in enumerate(soup.select("#stepDiv .media-body, .view_step_cont"), 1):
        txt = el.get_text(" ", strip=True)
        if txt:
            steps.append(f"{i}. {txt}")

    # 팁
    tips = []
    for i in range(1, len(steps) + 1):
        tip_el = soup.select_one(f"#stepdescr{i} > p")
        tip = tip_el.get_text(strip=True) if tip_el else ""
        tips.append(tip)

    return {
        "RECIPE_ID": recipe_id,
        "RECIPE_NM_KO": title,
        "SUMRY": summary,
        "SERVINGS": servings,
        "TY_NM": type_nm,
        "COOKING_TIME": cook_time,
        "LEVEL_NM": level,
        "INGREDIENT_FULL": json.dumps(ingredients, ensure_ascii=False).replace('"', "'"),
        "STEP_TEXT": json.dumps(steps, ensure_ascii=False),
        "STEP_TIP": json.dumps(tips, ensure_ascii=False),
    }

# ✅ 실행부
if __name__ == "__main__":
    for cat4, cat_name in CAT4_MAP.items():
        print(f"\n🌿 [START] {cat_name} (cat4={cat4}) 수집 시작")
        ids = get_recipe_ids_over100k(cat4, cat_name)
        print(f"[{cat_name}] 조회수 10만 이상 레시피 {len(ids)}개 발견")

        data_list = []
        for rid in ids:
            data = parse_recipe(rid, cat4=cat4)
            if data:
                data_list.append(data)
            time.sleep(random.uniform(1.0, 1.5))

        if data_list:
            df = pd.DataFrame(data_list)
            # 파일명에 사용할 수 없는 문자(예: / \ : * ? " < > |)를 언더스코어로 대체
            safe_cat = re.sub(r'[<>:"/\\|?*]', '_', cat_name)
            filename = f"recipes_over100k_{safe_cat}.csv"
            out_path = os.path.join(os.getcwd(), filename)
            df.to_csv(out_path, index=False, encoding="utf-8-sig")
            print(f"💾 {cat_name} 완료 — {len(df)}개 저장 → {out_path}")
        else:
            print(f"⚠️ {cat_name}: 수집된 데이터 없음")

        time.sleep(2.0)

    print("\n🎯 전체 cat4 수집 완료 — 모든 조회수 10만 이상 레시피 저장 완료!")
# Out:
# 🌿 [START] 국/탕 (cat4=54) 수집 시작
# [국/탕] page 1 완료 — 이번 9개 / 누적 9개
# [국/탕] page 2 완료 — 이번 13개 / 누적 22개
# [국/탕] page 3 완료 — 이번 11개 / 누적 33개
# [국/탕] page 4 완료 — 이번 14개 / 누적 47개
# [국/탕] page 5 완료 — 이번 8개 / 누적 55개
# [국/탕] page 6 완료 — 이번 4개 / 누적 59개
# [국/탕] page 7 완료 — 이번 10개 / 누적 69개
# [국/탕] page 8 완료 — 이번 5개 / 누적 74개
# [국/탕] page 9 완료 — 이번 4개 / 누적 78개
# [국/탕] page 10 완료 — 이번 9개 / 누적 87개
# [국/탕] page 11 완료 — 이번 6개 / 누적 93개
# [국/탕] page 12 완료 — 이번 9개 / 누적 102개
# [국/탕] page 13 완료 — 이번 5개 / 누적 107개
# [국/탕] page 14 완료 — 이번 10개 / 누적 117개
# [국/탕] page 15 완료 — 이번 4개 / 누적 121개
# [국/탕] page 16 완료 — 이번 5개 / 누적 126개
# [국/탕] page 17 완료 — 이번 6개 / 누적 132개
# [국/탕] page 18 완료 — 이번 6개 / 누적 138개
# [국/탕] page 19 완료 — 이번 3개 / 누적 141개
# [국/탕] page 20 완료 — 이번 2개 / 누적 143개
# [국/탕] page 21 완료 — 이번 6개 / 누적 149개
# [국/탕] page 22 완료 — 이번 4개 / 누적 153개
# [국/탕] page 23 완료 — 이번 3개 / 누적 156개
# [국/탕] page 24 완료 — 이번 6개 / 누적 162개
# [국/탕] page 25 완료 — 이번 3개 / 누적 165개
# [국/탕] page 26 완료 — 이번 5개 / 누적 170개
# [국/탕] page 27 완료 — 이번 4개 / 누적 174개
# [국/탕] page 28 완료 — 이번 3개 / 누적 177개
# [국/탕] page 29 완료 — 이번 4개 / 누적 181개
# [국/탕] page 30 완료 — 이번 9개 / 누적 190개
# [국/탕] page 31 완료 — 이번 1개 / 누적 191개
# [국/탕] 중단 (page 32) — 새로운 레시피 없음
# [국/탕] 조회수 10만 이상 레시피 191개 발견
# 💾 국/탕 완료 — 191개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_국_탕.csv
#
# 🌿 [START] 찌개 (cat4=55) 수집 시작
# [찌개] page 1 완료 — 이번 16개 / 누적 16개
# [찌개] page 2 완료 — 이번 9개 / 누적 25개
# [찌개] page 3 완료 — 이번 14개 / 누적 39개
# [찌개] page 4 완료 — 이번 12개 / 누적 51개
# [찌개] page 5 완료 — 이번 9개 / 누적 60개
# [찌개] page 6 완료 — 이번 6개 / 누적 66개
# [찌개] page 7 완료 — 이번 8개 / 누적 74개
# [찌개] page 8 완료 — 이번 6개 / 누적 80개
# [찌개] page 9 완료 — 이번 6개 / 누적 86개
# [찌개] page 10 완료 — 이번 5개 / 누적 91개
# [찌개] page 11 완료 — 이번 5개 / 누적 96개
# [찌개] page 12 완료 — 이번 5개 / 누적 101개
# [찌개] page 13 완료 — 이번 2개 / 누적 103개
# [찌개] page 14 완료 — 이번 9개 / 누적 112개
# [찌개] page 15 완료 — 이번 5개 / 누적 117개
# [찌개] page 16 완료 — 이번 1개 / 누적 118개
# [찌개] page 17 완료 — 이번 4개 / 누적 122개
# [찌개] page 18 완료 — 이번 5개 / 누적 127개
# [찌개] page 19 완료 — 이번 2개 / 누적 129개
# [찌개] page 20 완료 — 이번 3개 / 누적 132개
# [찌개] page 21 완료 — 이번 1개 / 누적 133개
# [찌개] page 22 완료 — 이번 3개 / 누적 136개
# [찌개] page 23 완료 — 이번 2개 / 누적 138개
# [찌개] 중단 (page 24) — 새로운 레시피 없음
# [찌개] 조회수 10만 이상 레시피 138개 발견
# 💾 찌개 완료 — 138개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_찌개.csv
#
# 🌿 [START] 면/만두 (cat4=53) 수집 시작
# [면/만두] page 1 완료 — 이번 9개 / 누적 9개
# [면/만두] page 2 완료 — 이번 8개 / 누적 17개
# [면/만두] page 3 완료 — 이번 3개 / 누적 20개
# [면/만두] page 4 완료 — 이번 5개 / 누적 25개
# [면/만두] page 5 완료 — 이번 8개 / 누적 33개
# [면/만두] page 6 완료 — 이번 5개 / 누적 38개
# [면/만두] page 7 완료 — 이번 3개 / 누적 41개
# [면/만두] page 8 완료 — 이번 3개 / 누적 44개
# [면/만두] page 9 완료 — 이번 6개 / 누적 50개
# [면/만두] page 10 완료 — 이번 6개 / 누적 56개
# [면/만두] page 11 완료 — 이번 1개 / 누적 57개
# [면/만두] 중단 (page 12) — 새로운 레시피 없음
# [면/만두] 조회수 10만 이상 레시피 57개 발견
# 💾 면/만두 완료 — 57개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_면_만두.csv
#
# 🌿 [START] 밥/죽/떡 (cat4=52) 수집 시작
# [밥/죽/떡] page 1 완료 — 이번 16개 / 누적 16개
# [밥/죽/떡] page 2 완료 — 이번 17개 / 누적 33개
# [밥/죽/떡] page 3 완료 — 이번 13개 / 누적 46개
# [밥/죽/떡] page 4 완료 — 이번 14개 / 누적 60개
# [밥/죽/떡] page 5 완료 — 이번 6개 / 누적 66개
# [밥/죽/떡] page 6 완료 — 이번 6개 / 누적 72개
# [밥/죽/떡] page 7 완료 — 이번 7개 / 누적 79개
# [밥/죽/떡] page 8 완료 — 이번 7개 / 누적 86개
# [밥/죽/떡] page 9 완료 — 이번 6개 / 누적 92개
# [밥/죽/떡] page 10 완료 — 이번 7개 / 누적 99개
# [밥/죽/떡] page 11 완료 — 이번 5개 / 누적 104개
# [밥/죽/떡] page 12 완료 — 이번 6개 / 누적 110개
# [밥/죽/떡] page 13 완료 — 이번 4개 / 누적 114개
# [밥/죽/떡] page 14 완료 — 이번 9개 / 누적 123개
# [밥/죽/떡] page 15 완료 — 이번 2개 / 누적 125개
# [밥/죽/떡] page 16 완료 — 이번 7개 / 누적 132개
# [밥/죽/떡] page 17 완료 — 이번 4개 / 누적 136개
# [밥/죽/떡] page 18 완료 — 이번 4개 / 누적 140개
# [밥/죽/떡] page 19 완료 — 이번 5개 / 누적 145개
# [밥/죽/떡] page 20 완료 — 이번 3개 / 누적 148개
# [밥/죽/떡] page 21 완료 — 이번 4개 / 누적 152개
# [밥/죽/떡] page 22 완료 — 이번 5개 / 누적 157개
# [밥/죽/떡] page 23 완료 — 이번 3개 / 누적 160개
# [밥/죽/떡] page 24 완료 — 이번 1개 / 누적 161개
# [밥/죽/떡] page 25 완료 — 이번 5개 / 누적 166개
# [밥/죽/떡] page 26 완료 — 이번 1개 / 누적 167개
# [밥/죽/떡] page 27 완료 — 이번 4개 / 누적 171개
# [밥/죽/떡] page 28 완료 — 이번 4개 / 누적 175개
# [밥/죽/떡] page 29 완료 — 이번 4개 / 누적 179개
# [밥/죽/떡] page 30 완료 — 이번 4개 / 누적 183개
# [밥/죽/떡] page 31 완료 — 이번 7개 / 누적 190개
# [밥/죽/떡] page 32 완료 — 이번 4개 / 누적 194개
# [밥/죽/떡] page 33 완료 — 이번 4개 / 누적 198개
# [밥/죽/떡] page 34 완료 — 이번 3개 / 누적 201개
# [밥/죽/떡] page 35 완료 — 이번 3개 / 누적 204개
# [밥/죽/떡] page 36 완료 — 이번 3개 / 누적 207개
# [밥/죽/떡] page 37 완료 — 이번 6개 / 누적 213개
# [밥/죽/떡] page 38 완료 — 이번 2개 / 누적 215개
# [밥/죽/떡] page 39 완료 — 이번 2개 / 누적 217개
# [밥/죽/떡] page 40 완료 — 이번 2개 / 누적 219개
# [밥/죽/떡] page 41 완료 — 이번 2개 / 누적 221개
# [밥/죽/떡] page 42 완료 — 이번 2개 / 누적 223개
# [밥/죽/떡] page 43 완료 — 이번 3개 / 누적 226개
# [밥/죽/떡] page 44 완료 — 이번 1개 / 누적 227개
# [밥/죽/떡] page 45 완료 — 이번 1개 / 누적 228개
# [밥/죽/떡] page 46 완료 — 이번 3개 / 누적 231개
# [밥/죽/떡] 중단 (page 47) — 새로운 레시피 없음
# [밥/죽/떡] 조회수 10만 이상 레시피 231개 발견
# 💾 밥/죽/떡 완료 — 231개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_밥_죽_떡.csv
#
# 🌿 [START] 퓨전 (cat4=61) 수집 시작
# [퓨전] page 1 완료 — 이번 1개 / 누적 1개
# [퓨전] page 2 완료 — 이번 3개 / 누적 4개
# [퓨전] 중단 (page 3) — 새로운 레시피 없음
# [퓨전] 조회수 10만 이상 레시피 4개 발견
# 💾 퓨전 완료 — 4개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_퓨전.csv
#
# 🌿 [START] 양식 (cat4=65) 수집 시작
# [양식] page 1 완료 — 이번 3개 / 누적 3개
# [양식] page 2 완료 — 이번 2개 / 누적 5개
# [양식] page 3 완료 — 이번 3개 / 누적 8개
# [양식] page 4 완료 — 이번 3개 / 누적 11개
# [양식] page 5 완료 — 이번 2개 / 누적 13개
# [양식] page 6 완료 — 이번 1개 / 누적 14개
# [양식] page 7 완료 — 이번 1개 / 누적 15개
# [양식] page 8 완료 — 이번 2개 / 누적 17개
# [양식] page 9 완료 — 이번 2개 / 누적 19개
# [양식] page 10 완료 — 이번 1개 / 누적 20개
# [양식] page 11 완료 — 이번 1개 / 누적 21개
# [양식] page 12 완료 — 이번 1개 / 누적 22개
# [양식] 중단 (page 13) — 새로운 레시피 없음
# [양식] 조회수 10만 이상 레시피 22개 발견
# 💾 양식 완료 — 22개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_양식.csv
#
# 🌿 [START] 샐러드 (cat4=64) 수집 시작
# [샐러드] page 1 완료 — 이번 13개 / 누적 13개
# [샐러드] page 2 완료 — 이번 4개 / 누적 17개
# [샐러드] page 3 완료 — 이번 1개 / 누적 18개
# [샐러드] page 4 완료 — 이번 3개 / 누적 21개
# [샐러드] page 5 완료 — 이번 4개 / 누적 25개
# [샐러드] page 6 완료 — 이번 3개 / 누적 28개
# [샐러드] page 7 완료 — 이번 4개 / 누적 32개
# [샐러드] 중단 (page 8) — 새로운 레시피 없음
# [샐러드] 조회수 10만 이상 레시피 32개 발견
# 💾 샐러드 완료 — 32개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_샐러드.csv
#
# 🌿 [START] 스프 (cat4=68) 수집 시작
# [스프] page 1 완료 — 이번 5개 / 누적 5개
# [스프] page 2 완료 — 이번 2개 / 누적 7개
# [스프] page 3 완료 — 이번 1개 / 누적 8개
# [스프] 중단 (page 4) — 새로운 레시피 없음
# [스프] 조회수 10만 이상 레시피 8개 발견
# 💾 스프 완료 — 8개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_스프.csv
#
# 🌿 [START] 기타 (cat4=62) 수집 시작
# [기타] page 1 완료 — 이번 1개 / 누적 1개
# [기타] 중단 (page 2) — 새로운 레시피 없음
# [기타] 조회수 10만 이상 레시피 1개 발견
# 💾 기타 완료 — 1개 저장 → c:\githome\Personalized_healthcare_Project\crawling\recipes_over100k_기타.csv
#
# 🎯 전체 cat4 수집 완료 — 모든 조회수 10만 이상 레시피 저장 완료!
